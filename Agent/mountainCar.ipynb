# %%
import random
import math
import os.path

import numpy as np
import pandas as pd
import gym
import time
env = gym.make('MountainCar-v0')
actions = [0,1,2]
NUM_BUCKETS = (6, 8)  # (x, x', theta, theta')
NUM_ACTIONS = env.action_space.n # (left, right)
STATE_BOUNDS = list(zip(env.observation_space.low, env.observation_space.high))

## Learning related constants
MIN_EXPLORE_RATE = 0.01
MIN_LEARNING_RATE = 0.1
# Out:
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.

# %%
def state_to_bucket(state):
    bucket_indice = []
    for i in range(len(state)):
        if state[i] <= STATE_BOUNDS[i][0]:
            bucket_index = 0
        elif state[i] >= STATE_BOUNDS[i][1]:
            bucket_index = NUM_BUCKETS[i] - 1
        else:
            # Mapping the state bounds to the bucket array
            bound_width = STATE_BOUNDS[i][1] - STATE_BOUNDS[i][0]
            offset = (NUM_BUCKETS[i]-1)*STATE_BOUNDS[i][0]/bound_width
            scaling = (NUM_BUCKETS[i]-1)/bound_width
            bucket_index = int(round(scaling*state[i] - offset))
        bucket_indice.append(bucket_index)
    return tuple(bucket_indice)

def get_explore_rate(t):
    return max(MIN_EXPLORE_RATE, min(1, 1.0 - math.log10((t+1)/25)))

def get_learning_rate(t):
    return max(MIN_LEARNING_RATE, min(0.5, 1.0 - math.log10((t+1)/25)))

# %%
class QLearningTable:
    def __init__(self, actions,reward_decay=0.99):
        self.actions = actions  # a list
        self.gamma = reward_decay
        self.q_table = pd.DataFrame(columns=self.actions, dtype=np.float64)

    def choose_action(self, observation, explore_rate):
        self.check_state_exist(observation)       
        if np.random.uniform() > explore_rate:
            # choose best action
            state_action = self.q_table.loc[observation, :]              
            action = state_action.idxmax()
        else:
            # choose random action
            action = np.random.choice(self.actions)          
        return action

    def learn(self, s, a, r, s_,lr):
        self.check_state_exist(s_)
        self.check_state_exist(s)       
        q_predict = self.q_table.loc[s, a]
        
        if s_ != 'terminal':
            q_target = r + self.gamma * self.q_table.loc[s_, :].max()
        else:
            q_target = r #si la partie se fini, on donne un full reward
            
        # update
        self.q_table.loc[s, a] += lr * (q_target - q_predict)

    def check_state_exist(self, state):
        if state not in self.q_table.index:
            # append new state to q table
            self.q_table = self.q_table.append(pd.Series([0] * len(self.actions), index=self.q_table.columns, name=state))

# %%
env = gym.make('MountainCar-v0')
qlearn = QLearningTable(actions=list(range(len(actions))))
learning_rate = get_learning_rate(0)
explore_rate = get_explore_rate(0)

for episode in range(200):
    
    obv = env.reset()
    previous_state = state_to_bucket(obv)
    
    v_max=obv[1] #vitesse max atteinte
    x_max=obv[0] #distance max atteinte
    
    for t in range(199):
        reward=0
        env.render()       
        #select an action
        rl_action = qlearn.choose_action(str(previous_state),explore_rate)
        #take an action 
        observation, _, done, info = env.step(rl_action)
        
        #observe the result
        bucket=state_to_bucket(observation)
        
        if observation[1]>v_max: #si la voiture dépasse la dernière limite de vitesse, elle a un reward
            v_max=observation[1]
            reward=1
        if observation[0]>x_max: #si la voiture est aller plus loin que la dernière fois, elle gagne un reward
            x_max=observation[0]
            reward=1
        
        
        previous_state=bucket
        
        if done:
            reward=100
            print('YEAH FINISH LINE')
            qlearn.learn(str(previous_state), rl_action, reward,'terminal',learning_rate)
            break
            
        #learn from previous action
        qlearn.learn(str(previous_state), rl_action, reward,str(bucket),learning_rate)        
        previous_state=bucket

    # Update parameters
    explore_rate = get_explore_rate(episode)
    learning_rate = get_learning_rate(episode)
    print("Episode ",episode," finished after {} timesteps".format(t+1))
            
env.close()
# Out:
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Episode  0  finished after 199 timesteps
# Episode  1  finished after 199 timesteps
# Episode  2  finished after 199 timesteps
# Episode  3  finished after 199 timesteps
# Episode  4  finished after 199 timesteps
# Episode  5  finished after 199 timesteps
# Episode  6  finished after 199 timesteps
# Episode  7  finished after 199 timesteps
# Episode  8  finished after 199 timesteps
# Episode  9  finished after 199 timesteps
# Episode  10  finished after 199 timesteps
# Episode  11  finished after 199 timesteps
# Episode  12  finished after 199 timesteps
# Episode  13  finished after 199 timesteps
# Episode  14  finished after 199 timesteps
# Episode  15  finished after 199 timesteps
# Episode  16  finished after 199 timesteps
# Episode  17  finished after 199 timesteps
# Episode  18  finished after 199 timesteps
# Episode  19  finished after 199 timesteps
# Episode  20  finished after 199 timesteps
# Episode  21  finished after 199 timesteps
# Episode  22  finished after 199 timesteps
# Episode  23  finished after 199 timesteps
# Episode  24  finished after 199 timesteps
# Episode  25  finished after 199 timesteps
# Episode  26  finished after 199 timesteps
# Episode  27  finished after 199 timesteps
# Episode  28  finished after 199 timesteps
# Episode  29  finished after 199 timesteps
# Episode  30  finished after 199 timesteps
# Episode  31  finished after 199 timesteps
# Episode  32  finished after 199 timesteps
# Episode  33  finished after 199 timesteps
# Episode  34  finished after 199 timesteps
# Episode  35  finished after 199 timesteps
# Episode  36  finished after 199 timesteps
# Episode  37  finished after 199 timesteps
# Episode  38  finished after 199 timesteps
# Episode  39  finished after 199 timesteps
# Episode  40  finished after 199 timesteps
# Episode  41  finished after 199 timesteps
# Episode  42  finished after 199 timesteps
# Episode  43  finished after 199 timesteps
# Episode  44  finished after 199 timesteps
# Episode  45  finished after 199 timesteps
# Episode  46  finished after 199 timesteps
# Episode  47  finished after 199 timesteps
# Episode  48  finished after 199 timesteps
# Episode  49  finished after 199 timesteps
# Episode  50  finished after 199 timesteps
# Episode  51  finished after 199 timesteps
# Episode  52  finished after 199 timesteps
# Episode  53  finished after 199 timesteps
# Episode  54  finished after 199 timesteps
# Episode  55  finished after 199 timesteps
# Episode  56  finished after 199 timesteps
# Episode  57  finished after 199 timesteps
# Episode  58  finished after 199 timesteps
# Episode  59  finished after 199 timesteps
# Episode  60  finished after 199 timesteps
# Episode  61  finished after 199 timesteps
# Episode  62  finished after 199 timesteps
# Episode  63  finished after 199 timesteps
# Episode  64  finished after 199 timesteps
# Episode  65  finished after 199 timesteps
# Episode  66  finished after 199 timesteps
# Episode  67  finished after 199 timesteps
# Episode  68  finished after 199 timesteps
# Episode  69  finished after 199 timesteps
# Episode  70  finished after 199 timesteps
# Episode  71  finished after 199 timesteps
# Episode  72  finished after 199 timesteps
# Episode  73  finished after 199 timesteps
# Episode  74  finished after 199 timesteps
# Episode  75  finished after 199 timesteps
# Episode  76  finished after 199 timesteps
# Episode  77  finished after 199 timesteps
# Episode  78  finished after 199 timesteps
# Episode  79  finished after 199 timesteps
# Episode  80  finished after 199 timesteps
# Episode  81  finished after 199 timesteps
# Episode  82  finished after 199 timesteps
# Episode  83  finished after 199 timesteps
# Episode  84  finished after 199 timesteps
# Episode  85  finished after 199 timesteps
# Episode  86  finished after 199 timesteps
# Episode  87  finished after 199 timesteps
# Episode  88  finished after 199 timesteps
# Episode  89  finished after 199 timesteps
# YEAH FINISH LINE
# Episode  90  finished after 172 timesteps
# Episode  91  finished after 199 timesteps
# Episode  92  finished after 199 timesteps
# Episode  93  finished after 199 timesteps
# Episode  94  finished after 199 timesteps
# YEAH FINISH LINE
# Episode  95  finished after 178 timesteps
# Episode  96  finished after 199 timesteps
# Episode  97  finished after 199 timesteps
# Episode  98  finished after 199 timesteps
# Episode  99  finished after 199 timesteps
# Episode  100  finished after 199 timesteps
# Episode  101  finished after 199 timesteps
# Episode  102  finished after 199 timesteps
# Episode  103  finished after 199 timesteps
# Episode  104  finished after 199 timesteps
# YEAH FINISH LINE
# Episode  105  finished after 171 timesteps
# YEAH FINISH LINE
# Episode  106  finished after 179 timesteps
# Episode  107  finished after 199 timesteps
# Episode  108  finished after 199 timesteps
# YEAH FINISH LINE
# Episode  109  finished after 180 timesteps
# Episode  110  finished after 199 timesteps
# YEAH FINISH LINE
# Episode  111  finished after 163 timesteps
# YEAH FINISH LINE
# Episode  112  finished after 172 timesteps
# Episode  113  finished after 199 timesteps
# Episode  114  finished after 199 timesteps
# YEAH FINISH LINE
# Episode  115  finished after 172 timesteps
# YEAH FINISH LINE
# Episode  116  finished after 168 timesteps
# YEAH FINISH LINE
# Episode  117  finished after 184 timesteps
# YEAH FINISH LINE
# Episode  118  finished after 198 timesteps
# Episode  119  finished after 199 timesteps
# Episode  120  finished after 199 timesteps
# Episode  121  finished after 199 timesteps
# YEAH FINISH LINE
# Episode  122  finished after 178 timesteps
# Episode  123  finished after 199 timesteps
# Episode  124  finished after 199 timesteps
# YEAH FINISH LINE
# Episode  125  finished after 166 timesteps
# Episode  126  finished after 199 timesteps
# YEAH FINISH LINE
# Episode  127  finished after 162 timesteps
# YEAH FINISH LINE
# Episode  128  finished after 161 timesteps
# YEAH FINISH LINE
# Episode  129  finished after 174 timesteps
# YEAH FINISH LINE
# Episode  130  finished after 167 timesteps
# Episode  131  finished after 199 timesteps
# Episode  132  finished after 199 timesteps
# Episode  133  finished after 199 timesteps
# Episode  134  finished after 199 timesteps
# Episode  135  finished after 199 timesteps
# YEAH FINISH LINE
# Episode  136  finished after 177 timesteps
# Episode  137  finished after 199 timesteps
# YEAH FINISH LINE
# Episode  138  finished after 192 timesteps
# Episode  139  finished after 199 timesteps
# Episode  140  finished after 199 timesteps
# Episode  141  finished after 199 timesteps
# Episode  142  finished after 199 timesteps
# YEAH FINISH LINE
# Episode  143  finished after 168 timesteps
# YEAH FINISH LINE
# Episode  144  finished after 169 timesteps
# YEAH FINISH LINE
# Episode  145  finished after 174 timesteps
# YEAH FINISH LINE
# Episode  146  finished after 160 timesteps
# YEAH FINISH LINE
# Episode  147  finished after 165 timesteps
# YEAH FINISH LINE
# Episode  148  finished after 173 timesteps
# Episode  149  finished after 199 timesteps
# YEAH FINISH LINE
# Episode  150  finished after 136 timesteps
# YEAH FINISH LINE
# Episode  151  finished after 164 timesteps
# Episode  152  finished after 199 timesteps
# YEAH FINISH LINE
# Episode  153  finished after 169 timesteps
# YEAH FINISH LINE
# Episode  154  finished after 178 timesteps
# YEAH FINISH LINE
# Episode  155  finished after 173 timesteps
# YEAH FINISH LINE
# Episode  156  finished after 175 timesteps
# YEAH FINISH LINE
# Episode  157  finished after 168 timesteps
# YEAH FINISH LINE
# Episode  158  finished after 166 timesteps
# YEAH FINISH LINE
# Episode  159  finished after 175 timesteps
# YEAH FINISH LINE
# Episode  160  finished after 162 timesteps
# YEAH FINISH LINE
# Episode  161  finished after 164 timesteps
# YEAH FINISH LINE
# Episode  162  finished after 162 timesteps
# YEAH FINISH LINE
# Episode  163  finished after 157 timesteps
# YEAH FINISH LINE
# Episode  164  finished after 165 timesteps
# YEAH FINISH LINE
# Episode  165  finished after 161 timesteps
# YEAH FINISH LINE
# Episode  166  finished after 171 timesteps
# Episode  167  finished after 199 timesteps
# YEAH FINISH LINE
# Episode  168  finished after 157 timesteps
# YEAH FINISH LINE
# Episode  169  finished after 162 timesteps
# YEAH FINISH LINE
# Episode  170  finished after 173 timesteps
# YEAH FINISH LINE
# Episode  171  finished after 172 timesteps
# YEAH FINISH LINE
# Episode  172  finished after 160 timesteps
# Episode  173  finished after 199 timesteps
# YEAH FINISH LINE
# Episode  174  finished after 162 timesteps
# YEAH FINISH LINE
# Episode  175  finished after 166 timesteps
# Episode  176  finished after 199 timesteps
# YEAH FINISH LINE
# Episode  177  finished after 126 timesteps
# YEAH FINISH LINE
# Episode  178  finished after 158 timesteps
# YEAH FINISH LINE
# Episode  179  finished after 162 timesteps
# YEAH FINISH LINE
# Episode  180  finished after 157 timesteps
# Episode  181  finished after 199 timesteps
# YEAH FINISH LINE
# Episode  182  finished after 165 timesteps
# YEAH FINISH LINE
# Episode  183  finished after 159 timesteps
# YEAH FINISH LINE
# Episode  184  finished after 161 timesteps
# YEAH FINISH LINE
# Episode  185  finished after 156 timesteps
# YEAH FINISH LINE
# Episode  186  finished after 163 timesteps
# YEAH FINISH LINE
# Episode  187  finished after 163 timesteps
# YEAH FINISH LINE
# Episode  188  finished after 160 timesteps
# YEAH FINISH LINE
# Episode  189  finished after 148 timesteps
# YEAH FINISH LINE
# Episode  190  finished after 154 timesteps
# YEAH FINISH LINE
# Episode  191  finished after 156 timesteps
# YEAH FINISH LINE
# Episode  192  finished after 163 timesteps
# YEAH FINISH LINE
# Episode  193  finished after 161 timesteps
# YEAH FINISH LINE
# Episode  194  finished after 161 timesteps
# Episode  195  finished after 199 timesteps
# YEAH FINISH LINE
# Episode  196  finished after 159 timesteps
# YEAH FINISH LINE
# Episode  197  finished after 159 timesteps
# YEAH FINISH LINE
# Episode  198  finished after 163 timesteps
# YEAH FINISH LINE
# Episode  199  finished after 158 timesteps

# %%
qlearn.q_table
# Out:
#                   0          1          2
# (3, 2)     0.000000   0.000000   0.000000
# (3, 3)    99.566603  99.721863  99.742636
# (2, 2)     0.000000   0.000000   0.000000
# (2, 3)    99.281401  99.344232  99.218432
# (4, 3)    98.187594  98.421095  98.325374
# (4, 2)     0.000000   0.000000   0.000000
# (1, 2)     0.000000   0.000000   0.000000
# (1, 3)    48.968632  43.435313  45.405002
# (2, 4)    81.584662  83.109935  83.417363
# (3, 4)    73.299741  73.295705  75.875208
# (2, 1)     0.000000   0.000000   0.000000
# (3, 1)     0.000000   0.000000   0.000000
# (4, 4)    48.097929  47.491201  49.564287
# (4, 1)     0.000000   0.000000   0.000000
# (1, 1)     0.000000   0.000000   0.000000
# (0, 2)     0.000000   0.000000   0.000000
# (5, 3)    73.817185  73.331657  76.344879
# (5, 2)     0.000000   0.000000   0.000000
# (0, 1)     0.000000   0.000000   0.000000
# (0, 3)     1.967469   1.713791   2.230916
# (1, 4)    48.180439  51.791802  49.480836
# (5, 4)    58.142260  60.616835  65.921919
# (5, 1)     0.000000   0.000000   0.000000
# (3, 0)     0.000000   0.000000   0.000000
# (2, 0)     0.000000   0.000000   0.000000
# (1, 0)     0.000000   0.000000   0.000000
# (6, 3)    68.925909  72.572376  70.457618
# (6, 2)     0.000000   0.000000   0.000000
# (4, 0)     0.000000   0.000000   0.000000
# (7, 3)    86.231943  99.718594  61.926436
# terminal   0.000000   0.000000   0.000000
# (6, 4)    34.411777  40.740165  49.224287
# (3, 5)     0.918933   0.000000   8.608606
# (7, 4)    42.034747  99.911551  99.860941
# (0, 0)     0.000000   0.000000   0.000000
# (2, 5)     0.000000   0.000000   0.333482
# (4, 5)     0.000000   0.000000   0.000000
# (7, 2)     0.000000   0.000000   0.000000
# (6, 1)     0.000000   0.000000   0.000000

# %%
'''env = gym.make('MountainCar-v0')
env.reset()
done=False
env.render() 
while not done:
        env.render()
        reward=0    
        #select an action
        rl_action = qlearn.choose_action(str(previous_state),0.01)
        #take an action 
        observation, _, done, info = env.step(rl_action)
        
        #observe the result
        bucket=state_to_bucket(observation)
env.close()
'''
# Out:
# "env = gym.make('MountainCar-v0')\nenv.reset()\ndone=False\nenv.render() \nwhile not done:\n        env.render()\n        reward=0    \n        #select an action\n        rl_action = qlearn.choose_action(str(previous_state),0.01)\n        #take an action \n        observation, _, done, info = env.step(rl_action)\n        \n        #observe the result\n        bucket=state_to_bucket(observation)\nenv.close()\n"
